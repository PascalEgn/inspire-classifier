# %%
import pandas as pd
from elasticsearch_dsl.connections import connections
from elasticsearch_dsl import Q, Search
import os
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
from tqdm.notebook import tqdm

# %%
df = pd.read_pickle("../inspire_classifier_dataset_2024-06-01_2024-07-31.pkl").sample(frac=1, random_state=42).reset_index(drop=True)

df.head(20)
# Out:
#          id                                inspire_categories  \
# 0   7543542                                       [Computing]
# 1   7567862                                                []
# 2   7692507                                 [General Physics]
# 3   7695458                           [Math and Math Physics]
# 4   7704966                                                []
# 5   7518703                                [Other, Computing]
# 6   7632345                                       [Computing]
# 7   7659434                                       [Computing]
# 8   7522006                                 [Instrumentation]
# 9   7705317                                [Condensed Matter]
# 10  7517390                                [Condensed Matter]
# 11  7533935                    [Other, Math and Math Physics]
# 12  7667925                                    [Accelerators]
# 13  7706450                                       [Computing]
# 14  7653088                           [Math and Math Physics]
# 15  7602708                                                []
# 16  7523667  [Data Analysis and Statistics, Computing, Other]
# 17  7677520                           [Math and Math Physics]
# 18  7637209                                       [Computing]
# 19  7582712                                           [Other]
#
#          category_sources  label  \
# 0                  [None]      0
# 1                      []      0
# 2                  [None]      0
# 3                 [arxiv]      0
# 4                      []      0
# 5          [arxiv, arxiv]      0
# 6                 [arxiv]      0
# 7                 [arxiv]      0
# 8                  [None]      0
# 9                 [arxiv]      0
# 10                [arxiv]      0
# 11         [arxiv, arxiv]      0
# 12                 [None]      0
# 13                [arxiv]      0
# 14                [arxiv]      0
# 15                     []      0
# 16  [arxiv, arxiv, arxiv]      0
# 17                [arxiv]      0
# 18                [arxiv]      0
# 19                [arxiv]      0
#
#                                                  text
# 0   Telecom Extreme Transformation <ENDTITLE> The ...
# 1   Improving demand forecasting in open systems w...
# 2   Induction of LTP mechanisms in dually innervat...
# 3   Small Ramsey numbers for books, wheels, and ge...
# 4   Anisotropy dependent spin orbit torque switchi...
# 5   HemoSet: The First Blood Segmentation Dataset ...
# 6   Reducing the Memory Footprint of 3D Gaussian S...
# 7   "There Has To Be a Lot That We're Missing": Mo...
# 8   High-efficiency vertically emitting coupler fa...
# 9   Effect of electronic correlation on topologica...
# 10  Nematic, chiral and topological superconductiv...
# 11  An SEIR network epidemic model with manual and...
# 12  Current-Limiting Characteristics of a Variable...
# 13  Constructing Concept-based Models to Mitigate ...
# 14  On the uniqueness of the strictly convex quadr...
# 15  The temperature dependent optical and scintill...
# 16  Distributional bias compromises leave-one-out ...
# 17  Curie--Weiss Model under $\ell^{p}$ constraint...
# 18  Inherent Challenges of Post-Hoc Membership Inf...
# 19  Intergroup violence in bursts or fizzles <ENDT...

# %%
class LiteratureSearch(Search):
    connection_holdingpen = connections.create_connection(
        hosts=["https://os-inspire-legacy-os1.cern.ch/es"],
        timeout=30,
        http_auth=(os.environ["ES_USERNAME"], os.environ["ES_PASSWORD"]),
        verify_certs=False,
        use_ssl=True,
    )
    connection_inspirehep = connections.create_connection(
        hosts=["https://os-inspire-prod.cern.ch/es"],
        timeout=30,
        http_auth=(os.environ["ES_USERNAME"], os.environ["ES_PASSWORD"]),
        verify_certs=False,
        use_ssl=True,
    )

    def __init__(self, index, **kwargs):
        if index == "holdingpen-hep":
            connection = LiteratureSearch.connection_holdingpen
        else:
            connection = LiteratureSearch.connection_inspirehep
        super().__init__(
            using=kwargs.get("using", connection),
            index=index,
        )

labels = ["rejected", "non_core", "core"]
df_test = pd.read_pickle("../classifier/data/test_data_corrected.df")
df_train_valid = pd.read_pickle("../classifier/data/train_valid_data.df")
DF_TO_CORRECT = df_test.copy()



df_rejected = DF_TO_CORRECT[DF_TO_CORRECT["label"] == 0]
df_rejected_sample = df_rejected.sample(frac=1, random_state=42).reset_index(drop=True)
# Out:
# /home/pascalegn/.pyenv/versions/3.11.7/envs/classifier/lib/python3.11/site-packages/elasticsearch/connection/http_urllib3.py:209: UserWarning: Connecting to https://os-inspire-legacy-os1.cern.ch:443 using SSL with verify_certs=False is insecure.
#   warnings.warn(
# /home/pascalegn/.pyenv/versions/3.11.7/envs/classifier/lib/python3.11/site-packages/elasticsearch/connection/http_urllib3.py:209: UserWarning: Connecting to https://os-inspire-prod.cern.ch:443 using SSL with verify_certs=False is insecure.
#   warnings.warn(

# %%
search_next = LiteratureSearch("holdingpen-hep")
search_hep = LiteratureSearch("records-hep")

counter = 0
for index, row in tqdm(df_rejected_sample.iterrows(), total=df_rejected_sample.shape[0]):
    document_id = row["id"]
    search_result = search_next.query(
        Q("match", _id=document_id) &
        Q("exists", field="metadata.arxiv_eprints")
    ).execute().hits
    if search_result:
        arxiv_eprints = search_result.hits[0]["_source"]["_extra_data"]["source_data"]["data"]["arxiv_eprints"]
        arxiv_ids = [arxiv["value"] for arxiv in arxiv_eprints]
        search_result_hep = search_hep.query(
            Q("terms", arxiv_eprints__value=arxiv_ids)
        ).execute().hits
        if search_result_hep:
            counter += 1
            print("arxiv_id", arxiv_ids)
            for hit in search_result_hep.hits:
                id = hit["_source"]["control_number"]
                DF_TO_CORRECT.loc[DF_TO_CORRECT['id']==row.id, 'id'] = int(id)
                print("id", id)
                if "core" in hit["_source"] and hit["_source"]["core"]:
                    print("core")
                    DF_TO_CORRECT.loc[DF_TO_CORRECT['id']==row.id, 'label'] = 2
                    
                else:
                    print("No core")
                    DF_TO_CORRECT.loc[DF_TO_CORRECT['id']==row.id, 'label'] = 1
                    
                print("------")
print(f"Out of {df_rejected_sample.shape[0]} rejected records, {counter} were found in the holdingpen-hep index.")
DF_TO_CORRECT.to_pickle("../classifier/data/test_data_corrected.df")
# Out:
#   0%|          | 0/17531 [00:00<?, ?it/s]
# arxiv_id ['2005.12653']
# id 1797938
# No core
# ------
# arxiv_id ['1912.07272']
# id 1770924
# No core
# ------
# arxiv_id ['1910.06224']
# id 1827639
# No core
# ------
# arxiv_id ['0809.5043']
# id 797925
# core
# ------
# arxiv_id ['2001.02897']
# id 1774701
# core
# ------
# arxiv_id ['2011.10412']
# id 1831959
# core
# ------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[146], line 16
#      12 arxiv_eprints = search_result.hits[0]["_source"]["_extra_data"]["source_data"]["data"]["arxiv_eprints"]
#      13 arxiv_ids = [arxiv["value"] for arxiv in arxiv_eprints]
#      14 search_result_hep = search_hep.query(
#      15     Q("terms", arxiv_eprints__value=arxiv_ids)
# ---> 16 ).execute().hits
#      17 if search_result_hep:
#      18     counter += 1
#
# File ~/.pyenv/versions/3.11.7/envs/classifier/lib/python3.11/site-packages/elasticsearch_dsl/search.py:723, in Search.execute(self, ignore_cache)
#     719         params = {"body": self.to_dict()}
#     720     params.update(self._params)
#     722     self._response = self._response_class(
# --> 723         self, es.search(index=self._index, **params)
#     724     )
#     725 return self._response
#
# File ~/.pyenv/versions/3.11.7/envs/classifier/lib/python3.11/site-packages/elasticsearch/client/utils.py:168, in query_params.<locals>._wrapper.<locals>._wrapped(*args, **kwargs)
#     166     if p in kwargs:
#     167         params[p] = kwargs.pop(p)
# --> 168 return func(*args, params=params, headers=headers, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/envs/classifier/lib/python3.11/site-packages/elasticsearch/client/__init__.py:1670, in Elasticsearch.search(self, body, index, doc_type, params, headers)
#    1667 if "from_" in params:
#    1668     params["from"] = params.pop("from_")
# -> 1670 return self.transport.perform_request(
#    1671     "POST",
#    1672     _make_path(index, doc_type, "_search"),
#    1673     params=params,
#    1674     headers=headers,
#    1675     body=body,
#    1676 )
#
# File ~/.pyenv/versions/3.11.7/envs/classifier/lib/python3.11/site-packages/elasticsearch/transport.py:381, in Transport.perform_request(self, method, url, headers, params, body)
#     378 connection = self.get_connection()
#     380 try:
# --> 381     status, headers_response, data = connection.perform_request(
#     382         method,
#     383         url,
#     384         params,
#     385         body,
#     386         headers=headers,
#     387         ignore=ignore,
#     388         timeout=timeout,
#     389     )
#     391 except TransportError as e:
#     392     if method == "HEAD" and e.status_code == 404:
#
# File ~/.pyenv/versions/3.11.7/envs/classifier/lib/python3.11/site-packages/elasticsearch/connection/http_urllib3.py:251, in Urllib3HttpConnection.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     248     body = self._gzip_compress(body)
#     249     request_headers["content-encoding"] = "gzip"
# --> 251 response = self.pool.urlopen(
#     252     method, url, body, retries=Retry(False), headers=request_headers, **kw
#     253 )
#     254 duration = time.time() - start
#     255 raw_data = response.data.decode("utf-8", "surrogatepass")
#
# File ~/.pyenv/versions/3.11.7/envs/classifier/lib/python3.11/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~/.pyenv/versions/3.11.7/envs/classifier/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.pyenv/versions/3.11.7/envs/classifier/lib/python3.11/site-packages/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/http/client.py:1386, in HTTPConnection.getresponse(self)
#    1384 try:
#    1385     try:
# -> 1386         response.begin()
#    1387     except ConnectionError:
#    1388         self.close()
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/ssl.py:1315, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1311     if flags != 0:
#    1312         raise ValueError(
#    1313           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1314           self.__class__)
# -> 1315     return self.read(nbytes, buffer)
#    1316 else:
#    1317     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
